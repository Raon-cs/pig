# %% [markdown]
# ## 환경설정

# %%
# 구글 드라이브 마운트
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 불러올 파일 위치 지정
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %% [markdown]
# ## 최초 설치

# %%
# !git clone https://github.com/ssaru/convert2Yolo.git
# Out:
# Cloning into 'convert2Yolo'...
# remote: Enumerating objects: 215, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 215 (delta 38), reused 35 (delta 35), pack-reused 172
# Receiving objects: 100% (215/215), 994.67 KiB | 11.05 MiB/s, done.
# Resolving deltas: 100% (95/95), done.

# %%
# %cd ./convert2Yolo
# Out:
# /content/drive/MyDrive/convert2Yolo

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %% [markdown]
# ## 구동 코드

# %%
import os
os.getcwd()
# Out:
# '/content/drive/MyDrive'

# %%
# !python ./convert2Yolo/example.py --datasets COCO --img_path ./추가/images1/ --label ./추가/labels1/annotations.xml --convert_output_path ./추가/result1/ --img_type ".jpg"  --manifest_path ./추가/result1/ --cls_list_file ./names.txt
# Out:
# Traceback (most recent call last):
#   File "./convert2Yolo/example.py", line 139, in <module>
#     main(config)
#   File "./convert2Yolo/example.py", line 58, in main
#     config["label"], config["img_path"])
# ValueError: not enough values to unpack (expected 3, got 2)
