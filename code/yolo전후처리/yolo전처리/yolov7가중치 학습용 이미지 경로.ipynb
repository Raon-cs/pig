# %%
# 구글 드라이브 마운트
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
from glob import glob

# 이미지 경로 list로 넣기
train_img_list = glob('/content/drive/MyDrive/yolov7/data/train2/images/*.jpg')

# txt 파일에 write
with open('./train2.txt', 'w') as f:
	f.write('\n'.join(train_img_list) + '\n')

# %%
from glob import glob

valid_img_list = glob('/content/drive/MyDrive/yolov7/data/valid/images/*.jpg')

with open('./valid.txt', 'w') as f:
	f.write('\n'.join(valid_img_list) + '\n')

# %%
from glob import glob

json_list = glob('/content/drive/MyDrive/pig/labels/*.json')

with open('./json_list.txt', 'w') as f:
	f.write('\n'.join(json_list) + '\n')
