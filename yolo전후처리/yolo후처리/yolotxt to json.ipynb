# %%
# 구글 드라이브 마운트
from google.colab import drive 
drive.mount('/content/drive')

# %%
# 불러올 파일 위치 지정
# %cd /content/drive/MyDrive/

# %%
import logging
logging.getLogger().setLevel(logging.CRITICAL)
# !pip install pylabel > /dev/null

# %%
from pylabel import importer

# %%
path_to_annotations = "/content/drive/MyDrive/yolov7/runs/detect/exp3/labels"
path_to_images = "/content/drive/MyDrive/yolov7/data/test/images/"

yoloclasses = ['Pig', '0']

dataset = importer.ImportYoloV7(path=path_to_annotations, path_to_images=path_to_images, cat_names=yoloclasses,
    img_ext="jpg", name="coco128")

# %%
dataset.df.head(5)
# Out:
#                                          img_folder  \
# id
# 0   /content/drive/MyDrive/yolov7/data/test/images/
# 1   /content/drive/MyDrive/yolov7/data/test/images/
# 2   /content/drive/MyDrive/yolov7/data/test/images/
# 3   /content/drive/MyDrive/yolov7/data/test/images/
# 4   /content/drive/MyDrive/yolov7/data/test/images/
#
#                                          img_filename img_path  img_id  \
# id
# 0   002877_jpg.rf.024763cbb2651d5c2c904149646d1e2e...                0
# 1   002877_jpg.rf.024763cbb2651d5c2c904149646d1e2e...                0
# 2   002877_jpg.rf.024763cbb2651d5c2c904149646d1e2e...                0
# 3   002877_jpg.rf.024763cbb2651d5c2c904149646d1e2e...                0
# 4   002877_jpg.rf.024763cbb2651d5c2c904149646d1e2e...                0
#
#     img_width  img_height  img_depth ann_segmented  ann_bbox_xmin  \
# id
# 0         416         416          3                   235.000064
# 1         416         416          3                    39.000000
# ...

# %%
dataset.export.ExportToCoco(cat_id_index=1)
# Out:
# ['/content/drive/MyDrive/yolov7/runs/detect/exp3/labels/coco128.json']
